# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/nikhiltripathi/Downloads/HR-Employee-Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
"""1. Deleting redundant columns.
2. Renaming the columns.
3. Dropping duplicates
4. Remove the NaN values from the datasets.
5. Cleaning individual columns
6. Check for some more Transformations."""
# Out:
# '1. Deleting redundant columns.\n2. Renaming the columns.\n3. Dropping duplicates\n4. Remove the NaN values from the datasets.\n5. Cleaning individual columns\n6. Check for some more Transformations.'

# %% [markdown]
# # 1. Deleting redundant columns

# %%
columns_to_keep = ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'HourlyRate', 'JobRole', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
columns_to_drop = ['EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', ]

# %%
data[columns_to_keep]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education  HourlyRate                    JobRole  \
# ...

# %%
data.drop(columns = columns_to_drop, inplace = True)

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education  HourlyRate                    JobRole  \
# ...

# %% [markdown]
# # 2. Renaming the columns

# %%
new_columns_to_keep = []

for i in columns_to_keep:
    new_columns_to_keep.append(i.upper())

# %%
data.columns = new_columns_to_keep

# %%
data.columns = (data.columns
.str.replace('YEAR', 'YEAR_')
.str.replace('ROLE', '_ROLE', regex=False)
.str.replace('RATE', '_RATE', regex=False)) # multiple replace statements

# %% [markdown]
# # 3. Dropping duplicates

# %%
(data.duplicated()).sum()
# Out:
# np.int64(0)

# %%
#Anyways
data.drop_duplicates(inplace = True)

# %% [markdown]
# # 4. Remove the NaN

# %%
data.isna().sum()
# Out:
# AGE                         0
# ATTRITION                   0
# BUSINESSTRAVEL              0
# DAILY_RATE                  0
# DEPARTMENT                  0
# DISTANCEFROMHOME            0
# EDUCATION                   0
# HOURLY_RATE                 0
# JOB_ROLE                    0
# YEAR_SATCOMPANY             0
# YEAR_SINCURRENT_ROLE        0
# YEAR_SSINCELASTPROMOTION    0
# YEAR_SWITHCURRMANAGER       0
# dtype: int64

# %%
#Anyways
data.dropna(inplace = True)

# %% [markdown]
# # 5. Cleaning individual columns

# %%
data
# Out:
#       AGE ATTRITION     BUSINESSTRAVEL  DAILY_RATE              DEPARTMENT  \
# 0      41       Yes      Travel_Rarely        1102                   Sales
# 1      49        No  Travel_Frequently         279  Research & Development
# 2      37       Yes      Travel_Rarely        1373  Research & Development
# 3      33        No  Travel_Frequently        1392  Research & Development
# 4      27        No      Travel_Rarely         591  Research & Development
# ...   ...       ...                ...         ...                     ...
# 1465   36        No  Travel_Frequently         884  Research & Development
# 1466   39        No      Travel_Rarely         613  Research & Development
# 1467   27        No      Travel_Rarely         155  Research & Development
# 1468   49        No  Travel_Frequently        1023                   Sales
# 1469   34        No      Travel_Rarely         628  Research & Development
#
# ...

# %%
data["BUSINESSTRAVEL"] = data["BUSINESSTRAVEL"].str.replace("Travel_", "")

# %%
data["ATTRITION"] = data["ATTRITION"].apply(lambda x:1 if x=="Yes" else 0)

# %% [markdown]
# # 6. More Transformations

# %%
data
# Out:
#       AGE  ATTRITION BUSINESSTRAVEL  DAILY_RATE              DEPARTMENT  \
# 0      41          1         Rarely        1102                   Sales
# 1      49          0     Frequently         279  Research & Development
# 2      37          1         Rarely        1373  Research & Development
# 3      33          0     Frequently        1392  Research & Development
# 4      27          0         Rarely         591  Research & Development
# ...   ...        ...            ...         ...                     ...
# 1465   36          0     Frequently         884  Research & Development
# 1466   39          0         Rarely         613  Research & Development
# 1467   27          0         Rarely         155  Research & Development
# 1468   49          0     Frequently        1023                   Sales
# 1469   34          0         Rarely         628  Research & Development
#
#       DISTANCEFROMHOME  EDUCATION  HOURLY_RATE                   JOB_ROLE  \
# ...

# %%
condition = (
    (data["BUSINESSTRAVEL"] == "Frequently") &
    (data["HOURLY_RATE"] >= 50) &
    (data["DAILY_RATE"] >= 1000) &
    (data["DISTANCEFROMHOME"] >= 5)
)

data["Free Bus Service"] = "No"  # Default value
data.loc[condition, "Free Bus Service"] = "Yes"

# %%
(data["Free Bus Service"] == "Yes").sum()
# Out:
# np.int64(42)

# %%
data
# Out:
#       AGE  ATTRITION BUSINESSTRAVEL  DAILY_RATE              DEPARTMENT  \
# 0      41          1         Rarely        1102                   Sales
# 1      49          0     Frequently         279  Research & Development
# 2      37          1         Rarely        1373  Research & Development
# 3      33          0     Frequently        1392  Research & Development
# 4      27          0         Rarely         591  Research & Development
# ...   ...        ...            ...         ...                     ...
# 1465   36          0     Frequently         884  Research & Development
# 1466   39          0         Rarely         613  Research & Development
# 1467   27          0         Rarely         155  Research & Development
# 1468   49          0     Frequently        1023                   Sales
# 1469   34          0         Rarely         628  Research & Development
#
#       DISTANCEFROMHOME  EDUCATION  HOURLY_RATE                   JOB_ROLE  \
# ...

# %%
data.columns = data.columns.str.replace(" ", "_")

# %%
data.columns = data.columns.str.upper()

# %%
data
# Out:
#       AGE  ATTRITION BUSINESSTRAVEL  DAILY_RATE              DEPARTMENT  \
# 0      41          1         Rarely        1102                   Sales
# 1      49          0     Frequently         279  Research & Development
# 2      37          1         Rarely        1373  Research & Development
# 3      33          0     Frequently        1392  Research & Development
# 4      27          0         Rarely         591  Research & Development
# ...   ...        ...            ...         ...                     ...
# 1465   36          0     Frequently         884  Research & Development
# 1466   39          0         Rarely         613  Research & Development
# 1467   27          0         Rarely         155  Research & Development
# 1468   49          0     Frequently        1023                   Sales
# 1469   34          0         Rarely         628  Research & Development
#
#       DISTANCEFROMHOME  EDUCATION  HOURLY_RATE                   JOB_ROLE  \
# ...

# %%
data["FREE_BUS_SERVICE"] = data["FREE_BUS_SERVICE"].apply(lambda x: 1 if x=="Yes" else 0)

# %%
data
# Out:
#       AGE  ATTRITION BUSINESSTRAVEL  DAILY_RATE              DEPARTMENT  \
# 0      41          1         Rarely        1102                   Sales
# 1      49          0     Frequently         279  Research & Development
# 2      37          1         Rarely        1373  Research & Development
# 3      33          0     Frequently        1392  Research & Development
# 4      27          0         Rarely         591  Research & Development
# ...   ...        ...            ...         ...                     ...
# 1465   36          0     Frequently         884  Research & Development
# 1466   39          0         Rarely         613  Research & Development
# 1467   27          0         Rarely         155  Research & Development
# 1468   49          0     Frequently        1023                   Sales
# 1469   34          0         Rarely         628  Research & Development
#
#       DISTANCEFROMHOME  EDUCATION  HOURLY_RATE                   JOB_ROLE  \
# ...

# %%
data["ATTRITION"] = data["ATTRITION"].astype(int)
data["FREE_BUS_SERVICE"] = data["FREE_BUS_SERVICE"].astype(int)

# %%
data.to_csv("Cleaned_HR_Employee_Attrition", index = False)

# %%
pd.read_csv("Cleaned_HR_Employee_Attrition")
# Out:
#       AGE  ATTRITION BUSINESSTRAVEL  DAILY_RATE              DEPARTMENT  \
# 0      41          1         Rarely        1102                   Sales
# 1      49          0     Frequently         279  Research & Development
# 2      37          1         Rarely        1373  Research & Development
# 3      33          0     Frequently        1392  Research & Development
# 4      27          0         Rarely         591  Research & Development
# ...   ...        ...            ...         ...                     ...
# 1465   36          0     Frequently         884  Research & Development
# 1466   39          0         Rarely         613  Research & Development
# 1467   27          0         Rarely         155  Research & Development
# 1468   49          0     Frequently        1023                   Sales
# 1469   34          0         Rarely         628  Research & Development
#
#       DISTANCEFROMHOME  EDUCATION  HOURLY_RATE                   JOB_ROLE  \
# ...
